# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from typing import List

class Solution:
    def singleNumber(self, nums: List[int]) -> int:
        # 我日异或，相同的元素异或为0，同时异或的结果与元素的分布顺序无关
        x = 0
        for num in nums:
            x ^= num
        return x
