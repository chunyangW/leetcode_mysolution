# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def mergeKLists(self, lists: List[Optional[ListNode]]) -> Optional[ListNode]:
        # 每两个作为一个顺序合并
        size = len(lists)
        if size == 0:
            return
        head = lists[0]
        for i in range(1, size):
            head2 = lists[i]
            head = self.merge(head, head2)
        return head
    def merge(self, list1, list2):
        head = ListNode()
        cur = head
        while list1 and list2:
            if list1.val < list2.val:
                cur.next = list1
                list1 = list1.next
            else:
                cur.next = list2
                list2 = list2.next
            cur = cur.next
        if list1:
            cur.next = list1
        elif list2: # 也要判断一下，假如两个同时没有了
            cur.next = list2
        return head.next

# %% [markdown]
# ## 虽然上面能过但是时间太长了
# ## 看到有人使用分治思想合并，也就是二分合并效率确实高
# ## 也有人维护最小堆，不断读取新数字

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def mergeKLists(self, lists: List[Optional[ListNode]]) -> Optional[ListNode]:
        # 每两个作为一个顺序合并
        size = len(lists)
        if size == 0:
            return
        
        while size > 1 : # 每次二分后更新长度 , 长度只有一个就结束
            mid = size // 2
            for i in range(mid):
                lists[i] = self.merge(lists[i], lists[size - i - 1])
            size = mid + size % 2  # 如果是奇数中间有一个没合并，所以需要加上这个长度（3 // 2 = 1）操作后 len = 1 + 1
        return lists[0]
    def merge(self, list1, list2):
        head = ListNode()
        cur = head
        while list1 and list2:
            if list1.val < list2.val:
                cur.next = list1
                list1 = list1.next
            else:
                cur.next = list2
                list2 = list2.next
            cur = cur.next
        if list1:
            cur.next = list1
        elif list2: # 也要判断一下，假如两个同时没有了
            cur.next = list2
        return head.next

# %% [markdown]
# ## 归并牛！！！
