# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 先判断 cur.next.val == cur.next.next.val
# 如果相等然后进入下面p = cur.next   while (p.val == p.next.val):   然后将p = p.next再不断移动直到最后不相等了
# 再 cur.next = p.next
# Definition for singly-linked list.
from typing import Optional

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        dummy_node = ListNode(0, head)  # next是head,val必须有值不然是将head给了val 
        cur = dummy_node
        while(cur.next != None):  # 删除要抓住上一个，所以当下一个没有的时候就不需要继续判断了
            if(cur.next.next and cur.next.next.val == cur.next.val):
                node = cur.next
                while(node.next !=None and node.val == node.next.val):
                    node = node.next
                cur.next = node.next  # 把东西都删了
               # cur = node.next  但是不能再移动cur了假如后面的也需要删，那么就任然需要前面有一个cur位于待删的前一个，所以不移动cur
            else:
                cur = cur.next
        return dummy_node.next

array = [1, 2, 3, 3, 4, 4, 5]
head = ListNode(array[0])
cur = head
for i in range(1, len(array)):
    node = ListNode(array[i])
    cur.next = node
    cur = cur.next

test = Solution()
head = test.deleteDuplicates(head)

# 显示当前链表
cur = head
while(cur):
    print(cur.val, end = "->")
    cur = cur.next
print("None")
# Out:
# 1->2->5->None

# %% [markdown]
# 上面的不能判断连续的删除情况
